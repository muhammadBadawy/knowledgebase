# %% [markdown]
# # Confidence intervals
#
# ![image.png](attachment:bf361063-06fd-41f6-ac96-525134cef08b.png)
#
# For the first part of the slide, we notice that the less our data is spread, the more we are more confident.
#
# and also the more data we have, the more confident we are.
#
# In this case, the mean might be five million and one or five million and two, I don't think we have enough evidence to say one or the other.
#
# ![image.png](attachment:3dc9752b-f959-454a-b729-db3a02430e1c.png)
#
# ![image.png](attachment:9ae9006d-0898-4d62-94e6-b9c26f0f306d.png)
#
# ![image.png](attachment:cc69015e-e770-4102-a8ef-31b8647bb063.png)

# %% [markdown]
# ---

# %% [markdown]
# Now let's have an API view
#
# ![image.png](attachment:d88ae6af-24b5-4dbf-9055-09093479674b.png)
#
# We already know that\
# ![image.png](attachment:64497a80-766b-40da-9650-798be4c74373.png)
#
# Then we got\
# ![image.png](attachment:f20c976d-87fd-4599-b5a2-7df48fe14feb.png)
#
# This will be for the 95% confidence interval since it's an interval.
#
# It has a lower end point and an upper end point
#
# at the lower end point is equal to $\mu - 1.96 \frac{\hat{\sigma}}{\sqrt{N}}$ and the upper end point is equal to $\mu + 1.96 \frac{\hat{\sigma}}{\sqrt{N}}$

# %% [markdown]
# ---
#
# Custom Confidence intervals
#
# ![image.png](attachment:5a749200-93dc-4ba9-8a42-7980370691f7.png)
#
# ![image.png](attachment:a66e931b-f49c-4c88-adae-42df6263e3f1.png)
#
# For the 95 percent confidence interval.
#
# It is simply the interval which covers the middle 95 percent of the area of this distribution.
#
# So we can simply say
#
# In general, the gamma confidence interval is the interval that covers the portion gamma of the area under the PDF.
#
# Let's have a further look
#
# ![image.png](attachment:541082bf-be55-4f57-92b8-afd3fdc20ae1.png)

# %% [markdown]
# ---
#
# Now let's take a deeper look
#
# ![image.png](attachment:0681bed9-acdc-4575-9628-d605c4204f66.png)
#
# ![image.png](attachment:8259fde9-5001-4061-8d8c-c65cd5e47048.png)
#
# In the next slides, I don't know why he considered the data points which are the Xs, as they are distributions,
#
# But the most logic point that I can think of is that every data point that are collected from the same experiment represents their distribution, and the expected value for each data point (before performing the experiment) is the mean
#
# Considering the steps of performing an experiment as follows:
# - thinking of doing an experiment
# - starting the experiment by doing for N times
#     - deciding to generate the data sample i (like tossing a coin for example)
#     - the expected value for that ith data point = E(the generation process of the data point i) = the mean of the distribution of the whole experiment $\mu$
#     - getting the value of ith data point
#     - repeat till i = N times
# - Ending the experiment
#
# ![image.png](attachment:457786d0-6ee6-4fe7-9bc6-fc8d6af18dff.png)
#
# ![image.png](attachment:aacbbb41-e4bb-451e-ba3c-e78b4c5a5c0a.png)
#
# So we come back to $\hat{\mu}$
#
# ![image.png](attachment:10faa178-706d-4ff7-8bf4-63df04d41ec7.png)
#
# The prev slide says the the $\hat{\mu}$ distribution mean is $\mu$ so let's prove it
#
# ![image.png](attachment:14e1da0f-fcff-4ae4-b598-f07dc44dffc0.png)
#
# And It also says the variance is $\frac{\hat{\sigma}^2}{N}$ , let's prove that too
#
# ![image.png](attachment:f6650bcc-2c4a-45e0-a750-03869a5f2dc0.png)
#
# Now finally
#
# ![image.png](attachment:e07ea979-4e74-42e4-92c5-6f68535a0cce.png)
#
# ![image.png](attachment:715b5b78-c22b-45ca-8d48-b9ac447323ba.png)
#
# OK, so this is a very intuitive idea behind the confidence interval, what we're trying to do is we're
#
# trying to create a distribution of the sample mean or any other quantity.
#
# We are trying to estimate the confidence interval is just an interval over this distribution.
#
# For example, you can choose the middle 95 percent.
#
# This is called the ninety five percent confidence interval.
#
# And from this intuitive example, we see that when the variance of our original data is larger, this makes our confidence interval larger.
# (the smaller the interval, the more we re sure about the actual mean -not the sample mean- we got from expecting the sample mean)
#
# However, we can shrink our confidence interval by collecting more data.
#
# That is, we can become more confident in our estimate by collecting more samples.
#
# OK, so more variance means larger and more samples mean smaller.

# %% [markdown]
# ---

# %% [markdown]
# Now let's take an example
#
# ![image.png](attachment:4380ec78-d7d5-4d27-8d1f-31432dccdaab.png)
#
# Now, due to symmetry, we can conclude that the answer for z right is +1.96
#
# ![image.png](attachment:8605291a-0e51-4e45-a5c9-b3f6860bed00.png)

# %% [markdown]
# OK, so what should you do when your data is not from the standard normal ?
#
# We use standardization, subtract the mean and divide by the variance
#
# ![image.png](attachment:cfa368b8-d82f-45ed-86c2-755186bb31eb.png)
#
# so what do we know about Z?
#
# Well, we know that if we want the lower and upper end points of the 95 percent confidence interval,
#
# these are what we just calculated, -1.96 and +1.96
#
# Now let's go backwards
#
# Our goal now is to isolate the parameter of interest to the mean $\mu$ so we can start by first multiplying everything
#
# ![image.png](attachment:826ba90e-c15b-4e16-a536-7de7b274c232.png)
#
# So now we got our desired confidence interval in the custom non standardized distribution
#
# ![image.png](attachment:9a395118-e729-4291-9de8-fd58415d86dc.png)

# %% [markdown]
# More generally, if we wanted the gamma confidence interval it would be the formula that you see here.
#
# OK, so you can think of this like the master formula for calculating the confidence interval.
#
# We'll call this the Z confidence interval since it's based on the standard normal.

# %% [markdown]
# Note that sometimes you'll see the confidence interval written in a different way.
#
# ![image.png](attachment:755ea66c-e48f-42ce-a397-926b1e56dc82.png)
#
# First note that since Z comes from the standard normal distribution, we can represent the middle ninety five percent as a probability.
#
# to note about this formula is that it is not interpreted as the probability that $\mu$ is between these values.
#
# Instead, recall that we are using the frequencies interpretation of statistics.
#
# What this means is that this is not a probability, but rather a relative frequency.
#
# In other words, it means that if I do some experiment many times, then 95 percent of those times the true $\mu$ will be contained in the confidence interval.
#
# At first this might sound strange, but in fact we can show encode that this is true.

# %% [markdown]
# Now, there's one small problem with the preceding derivation, if we look at a confidence interval
#
# ![image.png](attachment:fc02a07d-d3a5-44ec-9d20-e7bf4137660a.png)
#
# Remember that we only have the data.
#
# We don't know it's mean and typically we don't know its variance.
#
# Luckily, this can be simply approximated by using the sample variance.
#
# This is not precise, but it's a very common approximation to use in the real world.
#
# Furthermore, if you have lots of samples or in other words and is large and this becomes more accurate.
#
# Typically, statisticians use the unbiased estimate of the variance

# %% [markdown]
# ---

# %% [markdown]
# Now what about the means of distributions other than the normal distribution
#
# ![image.png](attachment:afa77858-4808-4801-b99e-ae55520a8e47.png)
#
# When we talk about $\mu$ note that because what you have is essentially the sum of many random variables.
#
# It converges to a normal distribution no matter what the distribution of the data is.
#
# Therefore, it's often the case that people use the Z confidence interval even when the data is not normally distributed.

# %% [markdown]
# ---

# %% [markdown]
# Now for an example
#
# To give you an example of this, let's consider how we would do this for the newly ran a variable,
#
# as you recall, these are coin flips, so the only possible values are zero.
#
# And one, it might surprise you to see that such a distribution might lead to a normal approximation.
#
# But if you plot a histogram of the sample, mean, you will find this to be true.
#
# ![image.png](attachment:d5d2ce28-67a4-49a9-94a8-3bc022b7b369.png)
#
# And then we can get back to our master formula to get the 95% confidence interval
#
# ![image.png](attachment:1e7fce2f-4386-4e9e-bad9-6492ddc9a068.png)
