# %% [markdown]
# # Projection interpretation for linear regression
#
# ![image.png](attachment:65f08ced-6f74-43c7-aa7a-c843d6deb02a.png)
#
# when we consider the design matrix X to be a transformation matrix, then the output of this transformation lays in a subspace at y space, and that's the exact output of the hypothesis
#
# But we know that the hypothesis isn't true 100%, so the true value of the y is far a bit from the output subspace by some noise, and that's the noise of real life.
#
# So our goal is to find a subspace that minimizes the noise for all values of y
#
# And from the above equations we get how to get the value of theta that minimizes the noise
#
# Hint : in the last equation look at the right part hand\
# first, this is how we get the value of single x in the space of y and it will be in the subspace (it will be an y hat)
#
# and since we know that y hat (the predicted y) equals X.theta, then we know how to get our minimizing theta
#
# And here when we look at theta, we will find that we reached the normal equation from the first analytical solution\
# at head of page 10
