# %% [markdown]
# # Week 2 content
#
# - Statistics:
#     - Random Variables
#     - Mean, variance, standard deviation
#     - Covariance, Correlation
# - Probability:
#     - Independence of events
#     - joint vs marginal probability

# %% [markdown]
# In some experiments we might not be directly interested in the outcome but interested in an event based on such outcomes  (sum of 2 from 2 die faces)
#
# We call this event a ‘variable’ that is ‘random’ and we are interested in the ‘probability’ of its occurrence.
#
# Example: Throwing two dice simultaneously. We might playing a game that is only interested in the sum of two dice not the value of each die. i.e., interested that the sum is 8 regardless that the dice rolled as {2,6}, {3,5},{4,4}.\
# So we want to know how likely this event will happen (getting the sum of 8 = our R.V. will be equal to 8)

# %% [markdown]
# ---
# Random variables can be categorized as:
# - Discrete: R.v set of possible values a finite (or countable) sequence x1, . . . , xn (cards, dice, etc)
# - Continuous: R.v. that take on a continuum of possible values in some interval (a, b) (lifetime of a car, driven distance between two locations, amount of water in a bottle, etc.)

# %% [markdown]
# We will focus on the discrete random variables and their probabilities.
#
# The Event of a random nmber can be any function: summation, difference, product, min, max, etc.
#
# The event space will be different than the original space of the outcomes (contains different values)
#
# Let's look at an example:\
# ![image.png](attachment:f98108b3-75ec-4b7a-bd3d-773db2807e5e.png)
#
# Lets revisit it again\
# ![image.png](attachment:def98c63-ea29-4d1b-9809-8b21533377ff.png)

# %% [markdown]
# Now let's get the probability fo every event\
# Then plot the PMF (prob. Mass function(discrete only))
#
# For P(X=xi)\
# ![image.png](attachment:eccb4850-c939-4dd6-9b33-e0fd380c6f4d.png)\
# And then the plot (PMF)\
# ![image.png](attachment:6f1eb5f2-453b-4923-bf16-93a8c00873d6.png)
#
# For P(Y=yi)\
# ![image.png](attachment:ceb89a40-61f2-4439-93ed-dc0aad1649a0.png)\
# And for the plot (PMF)\
# ![image.png](attachment:95f0b6ce-0d7a-401d-848d-8e7232ba477b.png)\

# %% [markdown]
# # Independent Random Variables (Independet Events)
#
# The random variables X and Y are said to be independent if for any two sets of real numbers A and B\
#
# P{X ∈ A,Y ∈ B} = P{X ∈ A}.P{Y ∈ B}\
# Or\
# P(X∩Y) = P(X).P(Y)
#
# Similarly, if X, Y and Z are independent, then:\
# P(X∩Y∩Z) = P(X).P(Y).P(Z)
#
# Note, “Independence” has nothing to do with “Mutuallyexclusive”.\
# MI events never happen at the same time (when tossing a coin, the result can either be heads or tails),\
# but Independent events can happen at the same time but they don’t imply each other (when tossing two coins, the result of one flip does not affect the result of the other or picking a ball from a box without replacement).
#
# ![image.png](attachment:4b7eb686-d9b8-4fdb-966f-54aabaf4a51e.png)

# %% [markdown]
# Theorem:
#
# If A and B are independent events, then their complements are independent as well
#
# P(A'∩B') = P(A').P(B')

# %% [markdown]
# Lesss go take a look at an example
#
# ![image.png](attachment:6d27dba1-9021-448c-9d60-1d383f82e1e6.png)
#
# Note that at 1:\
# the events are (non-defect from A, non-defect from B)
# and these event are
# - Not Mutualy Exclusive (both can happen at same time)
# - They are independent (If one happened, it doesn't imply or affect the other)
#
# Note that at 2:\
# the inner events (One defective and the other is non-defective) and these event are
# - Not Mutualy Exclusive (both can happen at same time)
# - They are independent (If one happened, it doesn't imply or affect the other)
#
# And another outter events (One defective and the other is non-defective) or (One defective and the other is non-defective
# - They are Mutualy Exclusive (both never happen at same time)
# - They not are dependent (If one happened, it imply the other didn't happen)
#
# Here was a special case of the dependent events where they are mutually exclusive
#
# Mutualy Exclusive -> negative relationship
# Independent -> no relationship at all
#
# ![image.png](attachment:b11b50e6-86f9-4790-9361-cd37d4df6b54.png)

# %% [markdown]
# # Wrap up
#
# We understand the meaning of a random variable and the difference between discrete and continuous r.v.
#
# We can assign probability to a r.v. that is based on one or more outcomes of a sample space.
#
# We can compute the probability of values taken by two r.v. if they are independent
#
# We will discuss now the probability of values taken by two r.v. if they are dependent and (not mutually exclusive) (joint)
#
# ---

# %% [markdown]
# # Joint and Marginal probabilities
#
# A joint probability distribution represents a probability distribution for two or more random variables. f(x,y) = P(X = x, Y = y)
#
# We sould know that the main purpose of this is to look for a relationship between two variables.
#
# Now let's take a look at an example:
#
# In an experiment we want to find the probability that the number “three” will occur “twice” when two dice are rolled --**at the same time**--.
#
# Number of possible outcomes when a die is rolled = 6 i.e. {1, 2, 3, 4, 5, 6}\
# Let X be the event of occurring 3 on first die and Y be the event of occurring 3 on the second die
#
# From the given table, the probability of a “three” occurring on each die is 1/6\
# P(X = 3,Y = 3) = 1/6
#
# ![image.png](attachment:f9a16145-c5c9-4f9e-802d-52a4611d5737.png)

# %% [markdown]
# Another Example:
#
# ![image.png](attachment:e2e87b69-1284-42b5-aec6-5b3aeb9c8381.png)

# %% [markdown]
# Joint and marginal probability
#
# ![image.png](attachment:f49e6e7c-844f-4a8e-b835-4012bddcf08d.png)

# %% [markdown]
# Example: Joint & Marginal probabilities
#
# ![image.png](attachment:5a2ac90e-5ab3-49a5-900e-4c1c1cf01ac3.png)
#
#
# ![image.png](attachment:79bc69d3-b914-4c43-ace5-097a5fadfe54.png)

# %% [markdown]
# # Mean, variance and std. deviation
#
# ![image.png](attachment:a33926aa-3221-4d2c-941f-dd0e689c53bd.png)
#
# ![image.png](attachment:cb572659-5479-4487-8100-0a7892a7d509.png)
#
# ![image.png](attachment:3d38ab6b-4d5d-4f55-a888-f64ff7bf6700.png)

# %% [markdown]
# Expected Value of X -E(X)- or we can call it mean:\
# ![image.png](attachment:52e1279f-4d59-4c47-9db3-eb70a30f15f3.png)
#
# We note that:\
# ![image.png](attachment:2909426d-543d-4d25-b221-43887f9b3e8d.png)
#
# So the mean is the sum of every value of the r.v X probability multiplied by it's probability
#
# Then what about dicrete rv?\
# ![image.png](attachment:905d17b1-e634-4caa-9883-2976fc543084.png)

# %% [markdown]
# Let's see an example:
#
# ![image.png](attachment:e5983f9e-9fce-4d40-92d9-a5d84908c548.png)

# %% [markdown]
# So here are some properties:
#
# ![image.png](attachment:5da71d94-c098-4c16-9531-63eee2b9c15a.png)

# %% [markdown]
# Now for the Variance
#
# ![image.png](attachment:8a8cba77-e84c-4412-a1a6-19c85b667a69.png)
#
# You can try to prove it using the properties of E(X)

# %% [markdown]
# Now for the standart deviation
#
# ![image.png](attachment:5fe2a42b-c65a-40cf-8012-689530e288b6.png)
#
# We can also say that the standard deviation is the average of (the differences of the data points and the mean)
#
# ![image.png](attachment:be4b8381-f44a-479b-a5ef-a81271c03f5e.png)

# %% [markdown]
# Why do i need the variance and standard deviation?
#
# ![image.png](attachment:60378f22-19d7-49a7-a0df-be3bb9013b56.png)
#
# ![image.png](attachment:4a7e9f1a-8e80-43af-beef-78eb3f6d2361.png)

# %% [markdown]
# Here is some Examples
#
# ![image.png](attachment:8105315d-4f66-4cc7-8947-5e2633965993.png)

# %% [markdown]
# And another one:
#
# ![image.png](attachment:9b970516-74b1-4ee0-8286-6feef0b0191b.png)

# %% [markdown]
# Properties of variance:
#
# ![image.png](attachment:2a1706cb-c7cd-4139-80aa-83c2a184fd3a.png)
#
# and for standard deviation:
#
# ![image.png](attachment:6e1fe369-aaee-401c-9ea0-2363100f3b86.png)
#
# we notice that the constant "a" didn't affect the standard deviation or the variance cuz it just shifts the PMF/PDF and don't affect the difference between the data points
#
# ![image.png](attachment:8128268a-a1fa-4f94-8b12-6a1272c72ae1.png)
#
# Now we aren't summing with a constant, we are summing with other variables.
