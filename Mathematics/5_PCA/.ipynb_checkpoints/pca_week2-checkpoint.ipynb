# %% [markdown]
# # Dot product, distance and angle between vectors
#
# Dot product is a special case of inner product
#
# If x and y are two vectors, their dot product is:
#
# $x^ty = \sum_{i=1}^n xiyi$
#
# The length of x is:
#
# $||x|| = \sqrt{x^tx} = \sqrt{\sum_{i=1}^nx_i^2}$

# %% [markdown]
# If we want the distance between x and y, we can just compute the length between the difference of those two vectors, like this:
#
# $d(x,y) = ||x - y|| = \sqrt{(x-y)^t(x-y)}$
#
# and the angle between then is:
#
# $\cos \alpha = \frac{x^ty}{||x|| ||y||}$

# %% [markdown]
# # exercises
# # 2-
# Compute the angle (in rad) between $\mathbf{x} = \begin{bmatrix}3\\4\end{bmatrix}$ and $\mathbf{y} = \begin{bmatrix}-1\\-1\end{bmatrix}$ using the dot product.

# %% [markdown]
# $x^ty = \begin{bmatrix}3 & 4\end{bmatrix} \begin{bmatrix}-1\\-1\end{bmatrix} = -3 -4 = -7$

# %% [markdown]
# $||x|| = \sqrt{\sum_{i=1}^nx_i^2} = \sqrt{9 + 16} = 5$
#
# $||y|| = \sqrt{\sum_{i=1}^ny_i^2} = \sqrt{1 + 1} = \sqrt{2}$
#
# > $\cos\alpha = \frac{-1}{5\sqrt{2}} =  2.99 rad$ (note that we use arc cos to calculate the angle in radius)
#
# Unless i'm crazy, some times the exercise gave me the vector y: (1,-1), then the answer is 1.71

# %% [markdown]
# # 3 -
# Compute the distance between $\mathbf{x} = \begin{bmatrix}3\\4\end{bmatrix}$ and $\mathbf{y} = \begin{bmatrix}1\\1\end{bmatrix}$
#
#
# $||x - y|| =|| \begin{bmatrix}2\\3\end{bmatrix}||$ = $ \sqrt{\begin{bmatrix}2&3\end{bmatrix}\begin{bmatrix}2\\3\end{bmatrix}}$

# %% [markdown]
# > => $\sqrt{4 + 9} = \sqrt{13} = 3.60$

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:3befc8bd-9c61-423b-8c59-7796386ecd4b.png)

# %% [markdown]
# # Inner product
#
# A inner product is a generalization of the dot product which we can also express length and sizes of vectors.
#
# A inner product is a symmetric positive definite bilinear mapping. Let's look on what this is?
#
# If we have two vectors in a vector space (V) , like this:
#
# >$x,y \in V$
#
# We take a mapping that takes two inputs from this vectors space: $<.,.> : VxV\rightarrow \mathbb{R}$

# %% [markdown]
# And this function have the properties above. let us discuss what those means:
#
# > Bilinearity
#
# If we have three vectors: x,y,z and a scalar: $\lambda$
#
# we can express linearity as:
#
# $<\lambda x + z, y> = \lambda <x,y> + <z,y>$\
# This means that the first argument (x+z) is linear. But we need bilinearity, right? So lets us make another requirement for bilinearity:
#
# $<x, \lambda y + z> = \lambda <x,y> + <x,z>$
#
# > Positive definite
#
# The inner product of x with itself is equal or greater than 0, and its equal to 0 only if x is a 0 vectors:
#
# $<x,x> \geq 0, <x,x> = 0 <=> x = 0$
#
# > Simmetry
#
# The inner product of <x,y> is equal to the inner product of <y,x> (order does not matter)

# %% [markdown]
# Any symmetric positive definite matrice produces a inner product! Look at this example:
#
# So the inner product form is as follows : $<x,y> = x^TAy$
#
# for A = $\begin{bmatrix} 2 & 1 \\ 1 & 2 \end{bmatrix}$
#
# $x^TAy = 2x_1y_1 + x_2y_1 + x_1y_2 + 2x_2y_2$ and this inner product is different from the dot product!
#
# If we have a symmetric positive definite matrice A: $\begin{bmatrix} 2 & 1 \\ 1 & 2 \end{bmatrix}$ , then it's a valid inner product

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:c6678118-abdc-4f30-86aa-fca32c67fcb0.png)

# %% [markdown]
# # important (optional):
#
# review the basis.pdf file, specially this part

# %% [markdown]
# # Inner products: Lenghts and distances
#
# The length of a vector can be definied as:
#
# $||x|| = \sqrt{<x,x>}$ (Note that the length is also called the norm of the vector)
#
# Let's look at an example of how to compute the inner product to find the length!
#
# To do this, first we need to define a inner product of x,y with a positive definite matrix:
#
# $<x,y> = x^t \begin{bmatrix} 1 & -1/2 \\ -1/2 & 1 \end{bmatrix}y$ and this operation gives us the following equation:
#
# $x_1y_1 -1/2(x_1x_2 + x_2y_1) + x_2y_2$
#
# And now we need to compute the length of X with our formula : $||x|| = \sqrt{<x,x>}$
#
# But how we find ||x|| do you ask? remember we are talking about symmetric matrices? we can get the equation for <x,x> if we subtstitute the y's in the equation above for x's (since the matrix is symmetric), so we get that :
#
# $<x,x> = x_1^2 -1/2(x_1x_2 + x_2x_1) + x_2^2$ and now:
#
# $||x|| = \sqrt{x_1^2-x_1x_2+x_2^2}$
#
# if our vectors x is (1,1), that gives us:
#
# $||x|| = \sqrt{1-1+1} = \sqrt{1} = 1$
#
# Note that the usual dot product ($x^ty$) would be equal to 2, so why the inner product gives us a different (smaller) answer?\
# because of $x_1x_2$ is the expression $\sqrt{x_1^2-x_1x_2+x_2^2}$
# - when $x_1x_2$ is possitive at the expression $\sqrt{x_1^2-x_1x_2+x_2^2}$ the norm become smaller the length
#
# and here we land on the second property, which is the triangle inequality,\
# which says that the norm of X plus Y is smaller or equal to than the norm of X plus the norm of Y
# $||x+y|| <= ||x|| + ||y||$

# %% [markdown]
# Some properties of the inner product:
#
# $||\lambda x|| = |\lambda| ||x||$
#
# $||x + y|| \leq ||x|| + ||y||$
#
# $|<x,y>| \leq ||x||. ||y||$

# %% [markdown]
# Let's look at the distance now!
#
# If we use a dot product, to calculate the distance,
# then the distance is called the Euclidean distance.
#
# $d<x,y> = ||x - y|| = \sqrt{<x-y>, <x-y>}$
#
# We get different answers here too from using the dot product! Did you find out why?
#
# That's because the dot product assume this same formula, but with a identity matrix multiplication: $x^TIy$, but our inner product uses any positive definite symmetric matrix: $x^TAy$

# %% [markdown]
# # Exercise
#
# ![image.png](attachment:a3c08d2d-8205-43fa-a160-8fd804318924.png)

# %% [markdown]
# # Angles and orthogonality with inner products
#
# the $cos(w) = \frac{x.y}{||x||.||y||}$ when we use A as I the indentity matrix
# the $cos(w) = \frac{<x,y>}{<x,x>.<y,y>}$ when we use A nothing other that I the indentiy matrix
#
# Note that we are getting the norm, we should take the value of A in condiseration, cuz if we used A as I the indentity matrix,\
# the nominator will be just a dot product (special case of the inner)\
# and the dominator will be the mutiple of Euclidean distances
#
# But if A isn't I the identety matrix,\
# the nominator will be just a general inner product\
# and the dominator will be the mutiple of inner products of the vectors with themselfs (not the Euclidean distances)
#
# If the inner product of two non-zero vectors is 0, they are orthogonal.
#
# Note that the you can have different inner products for the same vectors (using different A matrices), this means that two vectors may be orthogonal in respect to some inner products, and may not be in respect to others.
#
# Two orthogonal vectos have nothing in common besides the origin.
#
# We can also find basis for the vector space that are orthogonal to each other: $<b_i,b_j> = 0$ for i different than j
#
# And if we also use the inner product to normalize those basis vectos to every $||b_i|| = 1$, w**e have a orthonormal basis**.

# %% [markdown]
# ---
#
# # Important note
#
# revirew the week2_submission.ipynb notebook
#
# ---

# %% [markdown]
# # inner products of functions
#
# The inner products we discussed so far were
# defined for vectors with a finite number of entries,
# and we can think of these vectors as
# discrete functions with a finite number of function values.\
# The concept of an inner product can be
# generalized to continuous valued functions as well.\
# And then the sum over individual components of vectors turns into an integral,
# and the inner product between two functions is defined as follows.
#
# You can write that the inner product between two functions
# u and v as follows
#
# ![image.png](attachment:cdf71fdc-e5f7-4348-b2fa-0fad691ce647.png)
#
# Let's have a look at an example.\
# If we choose u of x equals
# Sine x and v of x is Cosine of x,
# and we define f of x to v,\
# u of x times v of x,
# which is a Sine x times Cosine x then we're going to end up with this function.
#
# ![image.png](attachment:215a1fad-25b6-47de-a530-d1c70ff63013.png)
#
# ![image.png](attachment:ee8a5a36-5778-4918-8ced-cc8157cb1f40.png)
#
# We see that this function is odd,\
# which means that f of minus x equals minus f of x.\
#
# If we choose the integral limit to be minus Pi and plus Pi then the
# integral of this product Sine of x times Cosine of x evaluates to zero.
# And that means that Sine and Cosine are Orthogonal
#
# if you look at a set of functions say one, Cosine x,
# Cosine of two x,
# Cosine three x and so on,
# that all of these functions are Orthogonal to
# each other if we integrate from minus Pi to plus Pi.
#
# ![image.png](attachment:e15c3917-58b3-41f5-9297-5f50ce8f6576.png)
#
# ---
# # inner products of random variables
#
# Another example for defining an inner product between
# unusual types are random variables or random vectors.\
# If we have two random variables,
# which are uncorrelated, then we know the following relationship.\
# We know that, the variance of x plus y is the variance
# of x plus the variance of y where x and y are random variables.\
#
# ![image.png](attachment:5d325740-57a0-43d3-a315-b6195fbd191a.png)
#
# Remember that variances are measured in squared units.
#
# This looks very much like the Pythagorean Theorem for right triangles,
# that one states that c squared equals a squared plus b squared.\
# If we look at triangles of this form where this is a,
# b, and this is c.
#
# ![image.png](attachment:e3e774f6-a26a-4621-a2d9-eb6dfc2f862b.png)
#
# ![image.png](attachment:4df995d7-bc13-435b-a679-028d9efb904b.png)
#
# Random variables can be considered vectors in a vector space and we can
# define inner products to obtain geometric properties of these random variables.
#
# If we define the inner product between two random variables between
# x and y to be the covariance between x and y.
#
# ![image.png](attachment:5a879d4c-d66a-47ad-a3a2-8efc2d5346aa.png)
#
# we see that the covariance is Symmetric,
# Positive Definite, and Linear.
#
# (So why the covariance matrix is a Symmetric, Positive Definite, and Linear matrix? becuse it is the inner product of random variables)
#
# So linearity would mean that
# the covariance of lambda times x plus y and z where x,
# y and z are random variables,
# and lambda is a real number,
# is lambda times the covariance between x and
# z plus the covariance between y and z.
#
# ![image.png](attachment:11a7dba5-f3d2-4bde-9ffd-7cf366f0d2bf.png)
#
# And if the length of a random variable is
# the square root of the covariance between of x with itself,
# which is the square root of the variance of x,\
# then this is the standard deviation of the random variable x.\
# So this is the length of a random variable.\
# Therefore, the zero vector is a vector that has no uncertainty,
# that means standard deviation is zero.
#
# ![image.png](attachment:1641557e-9963-4c36-a6e8-ab236ab4b0d2.png)
#
# If we now look at the angle between two random variables,
# we get the following relationship.\
# We get the Cosine of theta,
# which is the angle between two random variables is by
# definition the inner product between the two random variables,
# divided by the length of the first random variable,
# times the length of the second random variable.\
#
# ![image.png](attachment:5d67d48e-34a3-4687-b5d4-6a613a4731dd.png)
#
# (( VERY IMPORTANT NOTE : the covariance of 2 random variables devided by the multiplication of the lengthes (standard diviation) of these 2 random variables is just the corelation.))\
# ((So the corelation is just the $cos(\theta)$ between 2 random variables, and thats why it's between -1 and 1,\
# if -1 then the $\theta$ is 180,\
# and if 1 then the $\theta$ is 0\
# and if 0 then the $\theta$ is 90 and random variables are orthogonal and the projection is 0, so there is no relation between them))
#
# So if we can write the following form, $cos(\theta) = corelation(x,y) = \frac{<x,y>}{||x||.||y||} = \frac{cov(x,y)}{\sigma_x.\sigma_y}$
#
# And if we now write this out using the definition of our inner product,
# we get the covariance between x and y,
# divided by the square root
# of the variance of x,
# times the variance of y.
#
# ![image.png](attachment:d8ca77c8-25f1-44b8-91f3-745065534087.png)
#
# And this evaluates to zero if the covariance between x and y is zero,
# and that is the case when x and y are uncorrelated.
#
# Coming back now to our geometric interpretation,
# we would now replace a with the standard deviation of x,
# b is the standard deviation of y,
# and c is the square root of
# the variance of x plus the variance of y.
#
# ![image.png](attachment:d0b1c878-6777-454f-8bb2-95e83989c1ef.png)
#
# but how ?
#
# cuz we know that $\sigma(x) = \sqrt{var[x]}$
#
# ![image.png](attachment:7159dfdd-a878-4a5b-a058-a3b7215b122d.png)
#
# so $a^2 = \sqrt{var[x]}$\
# and $b^2 = \sqrt{var[y]}$\
# then $c^2 = \sqrt{var[x]}+\sqrt{var[y]}$\
#
# ---
#
# And this is how we get our geometric interpretation of random variables.
#
# the inner product allows us to think about lengths and angles between these objects.
# In the case of random variables,
# we saw that the variance of the sum of two uncorrelated random variables can
# be geometrically interpreted using the Pythagorean Theorem.
