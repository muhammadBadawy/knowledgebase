# %% [markdown]
# ---
# # Notes for Multivariate Calculus
#
# Hessian is a symmetric square matrix
#
# EVD can be applied to hessians and it will tell us a lot of information about the nature of the function.
#
# When a Hessian is a
# * PD or PSD -> it came from a convex function
# * ND or NSD -> it came from a inverted convex function
# * IN -> it came from a function with saddle points

# %% [markdown]
# ---
#
# Derivative of a vector
#
# ![image.png](attachment:2aa091e4-1063-4264-b7df-4692578b6318.png)
#
# Derivative of a matrix
#
# ![image.png](attachment:b4c10acf-d965-4ee1-997a-b0ddb9016533.png)
#
# Second derivative of a vector (Hessian)
#
# ![image.png](attachment:2dad113b-66a2-4c15-87f8-842b56480701.png)
#
# e.g (means for example)
#
# ![image.png](attachment:602e2fec-1a40-41be-9c7c-406966e552bf.png)
#
# --
#
# More tips and examples
#
# ![image.png](attachment:3da8cc47-6d52-4f7f-ab80-4362ea5357bd.png)
#
# ![image.png](attachment:44f77350-204a-4c81-9ca8-f07022d47fd5.png)
