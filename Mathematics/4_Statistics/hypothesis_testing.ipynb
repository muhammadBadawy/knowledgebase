# %% [markdown]
# #Null Hypothesis
#
# ![image.png](attachment:0be90996-e3e3-413e-954c-ebf8f81ae94c.png)
#
# ![image.png](attachment:58e75a17-75e5-429b-9008-f027b36ba3f7.png)
#
# ![image.png](attachment:fe3a5f64-b2c0-4dbb-9b95-ce161c2120fa.png)
#
# ![image.png](attachment:f3d17b89-9a91-46b4-82ea-7f7b3c54e06d.png)
#
# ![image.png](attachment:e0b7efc9-9312-45ea-83e2-043c706c229e.png)
#
# ![image.png](attachment:e06397a7-3dd2-4c63-8a1a-565b723e9585.png)
#
# ![image.png](attachment:556e9d05-c966-4233-9d08-691e2cf633d2.png)

# %% [markdown]
# # Alternative Hypothesis
#
# ![image.png](attachment:15b2f5a3-5213-4623-b2f5-2ce0b4f93df4.png)
#
# ![image.png](attachment:a156dac0-3206-4950-9f27-4bbc56fff761.png)
#
# ![image.png](attachment:94b95cb0-9fe9-451f-981b-e7498fcd71ee.png)
#
# ![image.png](attachment:86d892ba-3cac-47ef-b276-c029f609f453.png)
#
# ![image.png](attachment:e9ae323a-6ce0-47e9-8f26-10498dd718e7.png)
#
# ![image.png](attachment:9d860cf6-a226-476b-b563-3ca711f585b1.png)
#
# ![image.png](attachment:811bb1c2-88d8-47eb-8a8a-27029318e483.png)

# %% [markdown]
# ![image.png](attachment:4798defa-0630-4104-b3f4-695d6a94cfac.png)

# %% [markdown]
# ![image.png](attachment:dd54978b-0543-4913-ba40-6f88d0672376.png)

# %% [markdown]
# ![image.png](attachment:7b86cf7f-607e-424e-a4a2-3e9fe4cb6bc5.png)

# %% [markdown]
# ![image.png](attachment:47d5c1fc-7d5b-4c52-a000-07ee0b8ea301.png)

# %% [markdown]
# # If the $H_0$ is that a girl like you
#
# then
#
# ![image.png](attachment:99e90d61-45fc-43f8-af30-f955eea7c5b4.png)

# %% [markdown]
# I don't know how to interpret this image but it looks nice
#
# ![image.png](attachment:8f235adb-2a68-416a-9383-c40783a7f91b.png)
