# %% [markdown]
# # Some important notes to notice (this is not summary)
#
# these are just few notes from the last part of the third lecture of cs229 summer 2019
#
# So it's totally unreliable as a summary, it's just some written notes on what was said in the lecture

# %% [markdown]
# ---
# # Probability vs statistics
#
# In machine learning the goal is very different than the goal of statistics
# - In statistics the goal is to make statements the parameters of a model
# - In machine learning we don't care about the parameters at all (they are a black box for us), the goal to know how good is this model and making predictions about the future data
#
# ![image.png](attachment:27a86527-8a8a-46ae-95da-951e98fef9cb.png)
#
# Now to MLE (maximum likelihood estimation)
#
# ![image.png](attachment:9c4f4313-599e-4780-8707-29dc3aa53caf.png)
#
# ![image.png](attachment:5693a63b-70b1-4301-9cc6-4a78b45df94b.png)
#
# things to the right of the semicolon are given, not parameters of the function\
# At probability we want to find prediction based on mu and sigma we got\
# At Likelihood we use data to estimate parameters mu and sigma that maximizes the likelihood
#
# ![image.png](attachment:e808f690-dce9-46c6-afaf-3478d415f097.png)
#
# So again\
# At probability we want to find prediction based on mu and sigma we got\
# At Likelihood we use data to estimate parameters mu and sigma that maximizes the likelihood

# %% [markdown]
# ---
#
# Now let's make a general rule for $\theta$ which is any number of variables I want to get.
#
# ![image.png](attachment:2d7e63c4-6dc7-43df-b040-c6bceb603878.png)
#
# Log is monotonically increasing function
#
# I want the $\theta$ that maximizes the term
#
# So now let's apply for our multivariate guassian
#
# ![image.png](attachment:d8d9b8fd-2333-4e24-a9b9-db459cbda9ff.png)
#
# And since we are calculating the maximum likelihood, we want to get mu and sigma that gets me the max\
# So I'm going to get the derivative and set it to 0 to get the mu and sigma that gives me the max.\
# Here we are doing multivariate derivative, so we will get the derivative with respect to sigma for one time and for mu for the other time
#
# For mu\
# ![image.png](attachment:55b3ccc1-2b55-4bba-98d4-085935a8322e.png)
#
# for sigma\
#
# notice the trick here\
# ![image.png](attachment:a3d9c9d2-edd9-404b-9b66-eed91570c6d8.png)
#
# and then\
# ![image.png](attachment:5457a759-bc5d-4eaa-9210-11fa58f9a852.png)

# %% [markdown]
# ---
# # (supervised learning) intro to regression
#
# ![image.png](attachment:9ba329a5-e86f-4733-a70f-eb0437f9de6c.png)
#
# Here we notice that h is parameterized by $\theta$ (in classical statistics (like the prev examples), we used likelihood to get these $\theta$, but now in supervised learning, we just want to get h that is parameterized with $\theta$ as a whole function)
#
# ![image.png](attachment:8cda2f91-f756-48e2-8101-969327ccd414.png)
#
# $X^*$ here means new data point
